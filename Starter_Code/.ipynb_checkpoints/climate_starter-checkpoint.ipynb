# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, text, inspect, and_

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(autoload_with=engine)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
m = Base.classes.measurement

s =Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
most_recent = session.query(m.date).order_by(m.date.desc()).first()
most_recent
# Out:
# ('2017-08-23',)

# %%
session.query(func.min(m.tobs),func.avg(m.tobs),func.max(m.tobs)).filter(m.date=='2017-08-23').all()
# Out:
# [(76.0, 80.25, 82.0)]

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 
most_recent
# Calculate the date one year from the last date in data set.
last_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# Perform a query to retrieve the data and precipitation scores
q = session.query(m.date, m.prcp).filter(and_(func.date(m.date) >= '2016, 8, 23'),\
                                              func.date(m.date) <= '2017-8-23')

# Save the query results as a Pandas DataFrame. Explicitly set the column names
df = pd.DataFrame(q, columns=['date','prcp'])
# Sort the dataframe by date
df_sorted = df.sort_values(['date'])
# Use Pandas Plotting with Matplotlib to plot

# %%
last_date
# Out:
# datetime.date(2016, 8, 23)

# %%
session.query(func.min(m.tobs),func.avg(m.tobs),func.max(m.tobs)).filter(and_(func.date(m.date) >= '2016, 8, 23'),\
                                              func.date(m.date) <= '2017-8-23')

# %%
q

# %%
df = df.dropna()

# %%
df = df.sort_values(['date'])
# Out:
#             date  prcp
# 0     2016-01-01  0.00
# 3143  2016-01-01  0.00
# 1174  2016-01-01  0.00
# 2556  2016-01-01  0.02
# 2002  2016-01-01  0.00
# ...          ...   ...
# 594   2017-08-22  0.00
# 2555  2017-08-23  0.08
# 595   2017-08-23  0.00
# 1686  2017-08-23  0.00
# 3705  2017-08-23  0.45
#
# [3336 rows x 2 columns]

# %%
df_sorted.set_index('date', inplace=True)

# %%
df_sorted.plot(rot=45,figsize=[16,6],ylabel='Precipitation')
plt.title('Precipitation Over the Years')
# Out:
# Text(0.5, 1.0, 'Precipitation Over the Years')

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
df_sorted.info
# Out:
# <bound method DataFrame.info of             prcp
# date
# 2016-01-01  0.00
# 2016-01-01  0.00
# 2016-01-01  0.00
# 2016-01-01  0.00
# 2016-01-01  0.02
# ...          ...
# 2017-08-22  0.50
# 2017-08-23  0.00
# 2017-08-23  0.00
# 2017-08-23  0.08
# 2017-08-23  0.45
#
# [3706 rows x 1 columns]>

# %%
station
# Out:
# 9

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number of stations in the dataset
station = session.query(s.station).count()

# %%
# Design a query to find the most active stations (i.e. which stations have the most rows?)
# List the stations and their counts in descending order.
mAs = session.query(m.station,func.count()).group_by(m.station).order_by(func.count().desc()).all()
mAs
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
mAs = mAs[0][0]

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
session.query(func.min(m.tobs),func.avg(m.tobs),func.max(m.tobs)).filter(m.station==mAs).first()
# Out:
# (54.0, 71.66378066378067, 85.0)

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
results = session.query(m.tobs).filter((m.date>=last_date)&(m.station==mAs)).all()
df = pd.DataFrame(results)
df.hist(bins=12)
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.title('Temperature Observed')
plt.show()

# %%
last_date
# Out:
# datetime.date(2016, 8, 23)

# %% [markdown]
# # Close Session

# %%
# Close Session
session.close()
